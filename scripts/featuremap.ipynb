# %%
import numpy as np
import cv2
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
output = np.load('featuremap.npy')[0]
output.shape
# Out:
# (512, 8, 11)

# %%
pic = cv2.resize(output.sum(0),(224,224))

# %%
plt.imsave('sdas.png', pic)

# %%
pic = np.load('pic.npy')[0]
pic.shape
# Out:
# (3, 480, 640)

# %%
plt.imshow(cv2.resize(pic.transpose((1,2,0)),(224,224)))#[128:-128,208:-208])
